# %%
import json
from pprint import pprint

with open('data/season-bfa-2/page0.json') as f:
    data = json.load(f)

pprint(data)
# Out:
# {'leaderboard_url': 'https://raider.io/mythic-plus-rankings/season-bfa-2/all/world/leaderboards-strict',
#  'params': {'dungeon': 'all',
#             'page': 0,
#             'region': 'world',
#             'season': 'season-bfa-2'},
#  'rankings': [{'rank': 1,
#                'run': {'clear_time_ms': 2051592,
#                        'completed_at': '2019-02-05T16:38:30.000Z',
#                        'dungeon': {'expansion_id': 7,
#                                    'id': 9327,
#                                    'keystone_timer_ms': 2160999,
#                                    'name': 'Tol Dagor',
#                                    'short_name': 'TD',
#                                    'slug': 'tol-dagor'},
#                        'faction': 'horde',
#                        'keystone_platoon_id': None,
#                        'keystone_run_id': 1598489,
#                        'keystone_team_id': 31173579,
#                        'keystone_time_ms': 2160999,
# ...

# %%
pprint(data["rankings"][]["rank"])
# Out:
# 2
