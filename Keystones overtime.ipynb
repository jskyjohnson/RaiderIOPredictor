# %% [markdown]
# In this notebook I just want to create graphs for the best timed runs in each dungeon and see how they evolve over time. So I'm just going to create a graph that displays Y = Keystone Level, and X = day/period or something

# %%
#This is going to be a summation of all the servers. On specific dungeons
#So, Everything in RealmID, and Every period, Seperated with dungeon ID


#data/MythicLeaderboards/${connectedrealmid}/${dungeonid}/${periodid}.json

# %%
import matplotlib.pyplot as plt
import numpy as np
import json
from pprint import pprint
import os
from datetime import datetime

# %%
# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
X = [] #Datastuffffff
Y = []
Q = [] #time test
J = [] #rank

# %%
with open('data/test.json') as f:
    data = json.load(f)
    
for i in range(100):
    X.append(data['leading_groups'][i]['duration'])            
    Y.append(data['leading_groups'][i]['keystone_level'])
    
    #ts = (data['leading_groups'][i]['completed_timestamp'])/1000
    #hts = datetime.utcfromtimestamp(ts).strftime('%Y-%m-%d %H:%M:%S')
    Q.append(hts)
        
    
    J.append(data['leading_groups'][i]['ranking'])

# %%
#print(Q[1])
#plt.plot(Q, J)
#plt.show()

# %%
plt.plot(Y, X)
plt.show()
